# %%
import os
import numpy as np
from PIL import Image
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from torchvision.transforms import Compose, ToTensor, Resize, Normalize

# %%
class EyeDataset(Dataset):
    def __init__(self, img_paths, img_labels, transform=None):
        self.img_paths = img_paths
        self.img_labels = img_labels
        self.transform = transform

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_path = self.img_paths[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.img_labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
def load_data(img_dir):
    img_paths = []
    img_labels = []
    
    for img_file in os.listdir(img_dir):
        img_path = os.path.join(img_dir, img_file)
        if img_file.endswith('_bacterial.JPG'):
            img_paths.append(img_path)
            img_labels.append(0)
        elif img_file.endswith('_fungal.JPG'):
            img_paths.append(img_path)
            img_labels.append(1)
        
    print(f"Loaded {len(img_paths)} images.")  # Debugging line
    return img_paths, img_labels

# %%
def get_dataloaders(img_dir, batch_size):
    img_paths, img_labels = load_data(img_dir)
    
    # Split the data
    train_paths, temp_paths, train_labels, temp_labels = train_test_split(img_paths, img_labels, test_size=0.28, stratify=img_labels, random_state=42)
    val_paths, test_paths, val_labels, test_labels = train_test_split(temp_paths, temp_labels, test_size=0.7143, stratify=temp_labels, random_state=42)
    
    transform = Compose([
        Resize((300, 300)),
        ToTensor(),
        Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    train_dataset = EyeDataset(train_paths, train_labels, transform=transform)
    val_dataset = EyeDataset(val_paths, val_labels, transform=transform)
    test_dataset = EyeDataset(test_paths, test_labels, transform=transform)
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    return train_loader, val_loader, test_loader

# %%
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=5, padding=2),
            nn.BatchNorm2d(10),
            nn.ReLU(inplace=True),
            nn.Dropout(0.1),
            nn.Conv2d(10, 20, kernel_size=10, padding=5),
            nn.BatchNorm2d(20),
            nn.ReLU(inplace=True),
            nn.Dropout(0.1),
            nn.Conv2d(20, 30, kernel_size=20, padding=10),
            nn.BatchNorm2d(30),
            nn.ReLU(inplace=True),
            nn.Dropout(0.1)
        )
        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.classifier = nn.Sequential(
            nn.Linear(30, 15),
            nn.ReLU(inplace=True),
            nn.Dropout(0.1),
            nn.Linear(15, 5),
            nn.ReLU(inplace=True),
            nn.Dropout(0.1),
            nn.Linear(5, 1)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.global_avg_pool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
def train_model(model, criterion, optimizer, dataloaders, num_epochs, device):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()  # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            print("PRINT 1")
            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device).float().view(-1)
                print("PRINT 2")
                # Zero the parameter gradients
                optimizer.zero_grad()

                # Forward
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs).squeeze().float()  # This will change shape from [15, 1] to [15]
                    preds = torch.sigmoid(outputs).round()
                    print("PRINT 3")
                    # print("Outputs shape:", outputs.shape)  # Debugging output shape
                    # print("Labels shape:", labels.shape)
                    # print("Outputs:", outputs)
                    # print("Labels:", labels)
                    # print(outputs.dtype)  # Should be torch.float32 or similar
                    # print(labels.dtype)   # Should also be torch.float32 or similar
                    # print(torch.unique(labels))  # Should output tensor([0., 1.])
                    criterion = nn.BCEWithLogitsLoss()
                    loss = criterion(outputs, labels)


                    # Backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                        print("PRINT 4")
                # Statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds.view(-1) == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)
            print("PRINT 5")
            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # Deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                print("PRINT 6")
                best_model_wts = model.state_dict()

        print()

    print(f'Best val Acc: {best_acc:4f}')

    # Load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def evaluate_model(model, dataloader, device):
    model.eval()
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device).float()

            outputs = model(inputs)
            preds = torch.sigmoid(outputs).round()
            running_corrects += torch.sum(preds.view(-1) == labels.data)

    accuracy = running_corrects.double() / len(dataloader.dataset)
    print(f'Test Accuracy: {accuracy:.4f}')

# Main function

# %%
def main():
    img_dir = "bct_fng2"  # Update with your image directory
    batch_size = 15
    num_epochs = 150
    learning_rate = 0.001

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = CNNModel().to(device)
    class_weights = torch.tensor([1.5, 1.0]).to(device)
    criterion = nn.BCEWithLogitsLoss(pos_weight=class_weights)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    train_loader, val_loader, test_loader = get_dataloaders(img_dir, batch_size)
    dataloaders = {'train': train_loader, 'val': val_loader}

    model = train_model(model, criterion, optimizer, dataloaders, num_epochs, device)
    evaluate_model(model, test_loader, device)

# %%
if __name__ == "__main__":
    main()
# Out:
# Loaded 35 images.
# Epoch 0/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7497 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7136 Acc: 0.5000
# PRINT 6
#
# Epoch 1/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7425 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7088 Acc: 0.5000
#
# Epoch 2/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7387 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7074 Acc: 0.5000
#
# Epoch 3/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7403 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7076 Acc: 0.5000
#
# Epoch 4/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7305 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7084 Acc: 0.5000
#
# Epoch 5/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7285 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7063 Acc: 0.5000
#
# Epoch 6/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7272 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7049 Acc: 0.5000
#
# Epoch 7/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7267 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7039 Acc: 0.5000
#
# Epoch 8/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7219 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7019 Acc: 0.5000
#
# Epoch 9/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7218 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7007 Acc: 0.5000
#
# Epoch 10/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7290 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7028 Acc: 0.5000
#
# Epoch 11/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7157 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7035 Acc: 0.5000
#
# Epoch 12/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7145 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.7034 Acc: 0.5000
#
# Epoch 13/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7052 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6960 Acc: 0.5000
#
# Epoch 14/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7175 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6917 Acc: 0.5000
#
# Epoch 15/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7096 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6862 Acc: 0.5000
#
# Epoch 16/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7091 Acc: 0.4800
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6871 Acc: 0.5000
#
# Epoch 17/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6893 Acc: 0.5600
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6848 Acc: 0.5000
#
# Epoch 18/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6971 Acc: 0.5200
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6781 Acc: 0.5000
#
# Epoch 19/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.7182 Acc: 0.4400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6748 Acc: 0.5000
#
# Epoch 20/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6934 Acc: 0.4800
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6767 Acc: 0.5000
#
# Epoch 21/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6908 Acc: 0.5600
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6686 Acc: 0.5000
#
# Epoch 22/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6815 Acc: 0.5600
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6606 Acc: 0.5000
#
# Epoch 23/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6727 Acc: 0.5600
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6427 Acc: 0.5000
#
# Epoch 24/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6754 Acc: 0.6000
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6318 Acc: 0.5000
#
# Epoch 25/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6872 Acc: 0.6000
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6212 Acc: 0.5000
#
# Epoch 26/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6585 Acc: 0.6400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6249 Acc: 0.5000
#
# Epoch 27/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6649 Acc: 0.6400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6285 Acc: 0.5000
#
# Epoch 28/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6588 Acc: 0.6000
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6117 Acc: 0.5000
#
# Epoch 29/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6601 Acc: 0.6000
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6080 Acc: 0.5000
#
# Epoch 30/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6614 Acc: 0.6400
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.6181 Acc: 0.5000
#
# Epoch 31/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6638 Acc: 0.5200
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.5839 Acc: 1.0000
# PRINT 6
#
# Epoch 32/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6209 Acc: 0.7200
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.5556 Acc: 1.0000
#
# Epoch 33/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6380 Acc: 0.6800
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.5414 Acc: 1.0000
#
# Epoch 34/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6293 Acc: 0.6800
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.5600 Acc: 1.0000
#
# Epoch 35/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 2
# PRINT 3
# PRINT 4
# PRINT 5
# train Loss: 0.6226 Acc: 0.6800
# PRINT 1
# PRINT 2
# PRINT 3
# PRINT 5
# val Loss: 0.5478 Acc: 1.0000
#
# Epoch 36/149
# ----------
# PRINT 1
# PRINT 2
# PRINT 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[9], line 16, in main()
#      13 train_loader, val_loader, test_loader = get_dataloaders(img_dir, batch_size)
#      14 dataloaders = {'train': train_loader, 'val': val_loader}
# ---> 16 model = train_model(model, criterion, optimizer, dataloaders, num_epochs, device)
#      17 evaluate_model(model, test_loader, device)
#
# Cell In[7], line 45, in train_model(model, criterion, optimizer, dataloaders, num_epochs, device)
#      43 # Backward + optimize only if in training phase
#      44 if phase == 'train':
# ---> 45     loss.backward()
#      46     optimizer.step()
#      47     print("PRINT 4")
#
# File ~/anaconda3/envs/chashm1/lib/python3.12/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/anaconda3/envs/chashm1/lib/python3.12/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/anaconda3/envs/chashm1/lib/python3.12/site-packages/torch/autograd/graph.py:768, in _engine_run_backward(t_outputs, *args, **kwargs)
#     766     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     767 try:
# --> 768     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     769         t_outputs, *args, **kwargs
#     770     )  # Calls into the C++ engine to run the backward pass
#     771 finally:
#     772     if attach_logging_hooks:
#
# KeyboardInterrupt:
